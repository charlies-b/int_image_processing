# %%
import cv2

# %%
with open('int_image', 'rb') as fp:
    buff = fp.read()
len(buff)
# Out:
# 4915200

# %%
len(buff)/(960*1280)
# Out:
# 4.0

# %%
import numpy as np
buff[0:100]
# Out:
# b''

# %%
int.from_bytes(b'\x00\x00\x00\x02', byteorder='big')
# Out:
# 2

# %%
buff[0:4]
# Out:
# b'\x00\x00\x00\x02'

# %%
dt = np.dtype('uint32')
dt = dt.newbyteorder('>')
im = np.frombuffer(buff, dtype=dt) 
im = np.reshape(im, [960,1280])
im
# Out:
# array([[2, 1, 2, ..., 0, 2, 0],
#        [0, 0, 1, ..., 0, 0, 0],
#        [2, 1, 2, ..., 0, 2, 0],
#        ...,
#        [0, 0, 0, ..., 0, 0, 0],
#        [2, 0, 2, ..., 0, 2, 0],
#        [0, 0, 0, ..., 0, 0, 0]], dtype=uint32)

# %%
np.max(im)
# Out:
# 198

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.imshow(im, cmap='gray', vmin=0, vmax=255)

# %%
np.max(im)
# Out:
# 198

# %%
np.min(im)
# Out:
# 0

# %%
plt.figure(figsize=(10,10))
plt.imshow(im*50, cmap='gray', vmin=0, vmax=255)

# %%
img = cv2.imread('spatial-50mW-00-01_export.PNG')
img_grey = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img_grey, cmap='gray', vmin=0, vmax=255)

# %%
np.max(img_grey)
# Out:
# 225

# %%
np.max(np.round(im*(255/np.max(im))))
# Out:
# 255.0
